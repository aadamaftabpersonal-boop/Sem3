# %% [markdown]
# signal is a quantity that changes with one or more independent variables
# ex: temperature changes with hour --> T = f(t)
#
# every signal has dependent and independent variables
# ex: speech with time s(t)
#
# continuous signal doesnt mean continuous graph
# a continuous signal exists every instant of time x(t)
#
# graph has no gaps, not broken
#
# discrete graph - signals only exist at integer points of x
# x[n] = x(nT) T is the sampling period which need not be integer
#
# deterministic vs stochastic:
# deterministic - at a given time, the value of signal is known
# ex: x=6cos(5t)
#
# stochastic - at a given time, the value of signal is unknown
# ex: x=6cost(5t) + noise
#
# sampling:
# capturing signal at finite time intervals
# smaller t = more sample -> more accurate -> fps
#
# continuous periodic time signal => x(t) = x(t+T)
# discrete periodic time signal => x[n] = x[n+N], where N is an integer time period
#
# for addition of two signals, find LCM of the two rational periods
# addition of a periodic and non periodic signal is non periodic
#
# ![image.png](attachment:image.png)
#
# energy signal - happens, has finite total energy, avg power is zero
# ![image-3.png](attachment:image-3.png)
#
# power signal - infinite energy, avg power finite, always on
#
# ![image-2.png](attachment:image-2.png)
#
# Does it repeat forever?
#
# YES
# ↓
#
# Likely Power
#
# NO
# ↓
#
# Check Energy
#
# Finite?
#
# YES
#
# Energy Signal
#
# NO
#
# Neither
#
# Lec2
# every signal operation does:
# 1. height change
# 2. width change
# 3. flips graph
# 4. moves graph
#
# Operation1: amplitude scaling
# y(t) = ax(t)
# -2x(t) = scale twice, and flip about x axis
#
# Operation2: time scaling
# y(t) = x(bt)
# 0<b<1 -> expansion
# b>1 -> compression
#
# time reversal -> folding:
# replace t with -t
# reversal about y axis
#
# Operation3: delay and advance
# x(t-a) -> graph shape remains same but it shifts a units forward
#
# x(2t-4) = x(2(t-2)) -> 1st compress, 2nd push right
# x(-2t) = 1st compress, 2nd reverse about y axis
#
# say i have a feed
# keeping only integer time signals and removing others is called downsampling
#
# say my sample is less and i want more samples
# i can do x(t) -> x(t/2)
#
# Lec3
# unit step func:
# unit step is defined as:
# ![image-4.png](attachment:image-4.png)
#
# also called heaviside step function
# ![image-4.png](attachment:image-4.png)
#
# why do we need it? it lets turn us signals off
# ![image-5.png](attachment:image-5.png)
# switches off before t=0 and switches on at t=0
#
# constructing a signal only between 0 and 1
# u(t)-u(t-1)
# this is how we construct pulse
#
# applications:
# 1. digital communication
# 2. image processing
# 3. sampling
# 4. radar
# basically wherever a signal exists briefly
#
# impulse signal:
# infinitely large near t=0, almost zero elsewhere, total integral equals to 1
# height isnt defined
#
# ![image-6.png](attachment:image-6.png)
# the delta extracts value at t=0
#
# ![image-7.png](attachment:image-7.png)
#
# for transformation of signals
# always do  xnew = T(xold) and transform as per the info
#
# two frequencies are said to be harmonically related if they are multiples of the same common frequency and distinct if they are then we can safely say
#     P^2  = P1 ^2 + P2 ^ 2
# and in such cases the cross terms have zero average
#
# for a given signal:
# x(t) = xeven(t) + xodd(t)
# x(-t) = xeven(t) - xodd(t)
#
# xeven(t) = (x(t) + x(-t))/2
# xodd(t) = (x(t)-x(-t))/2
#
# just add graphs (superimpose)
#
# SIGNAL TRANSFORMATIONS:
# y(t) = x(at+b)
# atnew + b = xold
# xnew = (xold - b)/a
#
# x(t-b) -> tnew-b = told -> told + b = tnew -> shift old by b units with sign obvio
#
# 2D transformations:
# g(x, y) = f(ax+by, cx+dy)
# xold = axnew+bynew
# yold = cxnew + dynew
#
# Periodicity:
# continuous signal:
# x(t) = x(T+t)
#
# discrete signal:
# x[n] = x[n+N]
#
# ![image-8.png](attachment:image-8.png)
#
# if periods of signals = t1, t2
#
# sinAcosB = [sin(A+B) + sin(A-B)]/2
# sinAsinB = [cos(A-B) - cos(A+B)]/2
#
# harmonically related frequencies:
# frequencies that are multiples of a common frequency
#
# CONVERTING sin/cos into complex exponentials
# cos = [ejtheta + e-(jtheta)]/2
# sin = [ejtheta - e(-jtheta)]/2
#
# 1/j = -j
#
# ![image-9.png](attachment:image-9.png)
# ![image-10.png](attachment:image-10.png)
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
# r>0 provides exponential or decaying
# and imaginary component provides rotation
#
# ![image-13.png](attachment:image-13.png)
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-14.png](attachment:image-14.png)
#
# ![image-15.png](attachment:image-15.png)
#
# ![image-16.png](attachment:image-16.png)
#
# ![image-18.png](attachment:image-18.png)
#
# ![image-19.png](attachment:image-19.png)
#
# a system is said to be memoryless when the output of that system only depends on the input at that given time
#
# ![image-20.png](attachment:image-20.png)
# infinite memory
#
#
# a system is said to be invertible if each input produces a distinct output
#
# a system is said to be causal if the output only depends on the present and past
#
# all memoryless systems are causal
#
# y(t) = x(t)cos(t+1) is causal and memoryless
#
# bounded in bounded out stability - if for small inputs outputs are reasonable and do not diverge then the system is said to be BIBO
#
# time invariant
# say y(t) = x(t)
# y(t-to) = x(t-to)
# verify if even after delay x(t-to) remains y(t-to)
#
# ![image-21.png](attachment:image-21.png)

# %% [markdown]
# every signal can have operations:
# turn parts on and off -> u(t)
# pick out one exact instant -> d(t)
# shift it
# scale it
# ask whether it repeats -> periodicity
# represent oscillations elegantly -> complex exponentials
#
# u(t-a) - u(t-b) gives window (a, b)
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# ![image-3.png](attachment:image-3.png)
