# %% [markdown]
# terminal emulator - a program that lets run terminal in a graphical manner - like windows terminal
# mkdir - to make a directory
# shell is a command line interface that takes our commands and performs desired operations by the OS
# docker run -it ubuntu - gives root(username) and @ name of server
# whenever we run python3, git, docker all these are executable files that the OS understands
# which python3, git, docker tells where is executable file
# which python3 shows the exact executable path in your current $PATH (e.g., /usr/bin/python3).
# whereis python3 shows the binary location along with source and manual page files.
# ls lists everything in that directory
# cd means change directory - to come to one directory use cd directory name
# cd .. - go to parent
# cd . - just one level above
# open . - opens current folder
# echo $PATH spits out list of all system's PATH environment variable
# echo is also an executable file
# ls -a means show all files including hidden. means current directory .. means previous directory
# cat filename - shows contents of file
# export MY_PATH="value" creates an variable only valid for a particular session
# pwd - tells present working directory
# ls -l = shows user, groups, permission and stuff
# ls -la = shows all files with permissions, and other info
# ls -R: shows folder and subdirectories
# ls -aR: shows all folders and subdirectories
# ls -alR: shows all folders and subdirectories including hidden and all permissions too
# cat > filename - to enter contents in that file, creates a file
# cat - takes all file contents and dumps into stdio
# > - redirect operator
# man - manual; opens documentation inside a terminal pager
#
# cat f5.txt | tr a-z A-Z > f5.txt
# The shell processes > f5.txt first, which wipes the file empty before any command runs. When cat tries to read f5.txt, it ends up reading a completely empty file.
#
# mkdir -p random/middle/hello - to create a directory between random and hello
# touch filename - to create file
# cp filename copyfilename = to copy contents from one file to another
# mv source_files dest - move files from one place to another or rename a file
# and to do both mv filename directory/newfilename
# rm - remove files or directories
# rmdir - removes directories
# rm -R - remove all subdirectories
#
# sudo command = super user do - when needed permissions u do this, it asks for authentication
# df - display check free disk space/ report file system space usage
# du - tells disk usage statistics
#
# cat vs more
# cat dumps everything in the file, more shows paginated view. navigation - none in cat, scrolling in more. piping and redirection there in cat, not there in more
# cat - small files, piping into tools, etc. use case
# more - to read large files
#
# head -n howmanylinestodisplay
# tail -n howmanylinestodisplay
# by default 10 lines
#
# diff file1 file2
# find differences in the two files
#
# find- finds the directory/file and lists everything inside it
# find . -type d - finds sub_directories in the folder
# find . -type f - finds all files
# find . -type f -name filename - finds that filename
# find . -type f -mmin -20 - finds all files edited/changed in the last 20 mins
# find . -type f -mtime -x - finds all files modified in the last x days
# find . -type f -maxdepth -d - finds all files till depth d
#
# 3 types of permission read write execute
# chmod - to change file permissions
# chmod u=rwx,g=rw,o=r filename
#
# 4 stands for read, 2 stands for write, 1 stands for execute, 0 means no permissionx t
# so 5 = rx, 6=rw, so on
#
# sudo chown newowner filename - gives access to new owner need sudo
# sudo cat filename - to read file without the permissions
#
#
# find . -type f -name "*.txt" - to find all txt files
# find . -type f -name "*.txt" -exec rm -rf {} + = delete all files of txt type + for all including all files
# grep - global regular expression print
# grep -V = to check version of grep
# grep -w text file = finds the word containing the text in the file and returns it
# grep -i text file = finds word containing the text in the file (case sensitive off) and returns it
# grep -n text file = get line number of word containing the text in the file
# grep -B l text file = get last l lines before the line containing the text and that line too
# rm -r -f = remove recursively forcefully
# grep -win "rahul" ./ .txt - find text files with rahul
# grep -rwin "rahul" ./ .txt - find text files with rahul recursively
#
# grep -winl "rahul" . - returns all files with rahul in them
# grep -wirc "rahul" . - returns count of rahul in all files and folders in the directory
#
# history - to get log of all commands run on terminal till that point
#
# history | grep "kunal" - gives log of all commands run containing kunal
#
# grep -P "\w" companies.txt - finds all words in companies.txt
#
# alias - short hand forms for commands
#
# sort companies.txt- sorts and prints
# ping site.com - to ping site
# top - to show all running processes
#
# uname = which kernel being used
# kill - to kill a process
#
# zip folder name filename - zips file into folder
# unzip - unzips
# hostname - tells name of host currently using
#
# sudo useradd User - to add user
# sudo passwd user - to set password for user
# sudo userdel User - to delete user
#
# uname - kernal name
# uname -o - kernel distribution
# uname -r - kernel version
# cpu details
#
# the free command displays the total amount of free and used physical memory (RAM) and swap space in the system, along with buffers and caches used by the kernel.
# free -h prints it out in human readable format
# free -m prints in megabytes
#
# getent - fetches entries from the name service switch (NSS)
# getent passwd aadam - finds location of password
# id user - gives id of user
# lsof = lists all open files
# nslookup google.com - gives info about the website, dns server anol
# cut -c 1-2 companies.txt - columnwise cutting - 1-2 gives first two characters
#
# ps:
# Displays processes associated with the current terminal session (shows PID, TTY, TIME, CMD)
# zczhx || echo "hi" - prints error but prints hi too
# rm -r !(names.txt) = deletes everything but names.txt
# echo "hey">>names.txt =appends hey to names.txt
# echo "hey">names.txt = overwrites names.txt
#
# echo "hey" && {echo "hi"; echo "i am good"} - && means first should execute for second to execute
# strace ____ = to trace all syscalls while running the command
# ltrace = shows library level calls
#
# Your program
#      ↓
# Library function
#      ↓
# System call
#      ↓
# Kernel
#      ↓
# Hardware/resource
#
# objdump -d filename - displays all sets of instructions
#
# ELF = executable and linkable format
# executables are cpu and os dependent
# ldd ./hello = shows dynamic library dependencies for hello file
