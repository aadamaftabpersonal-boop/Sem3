# %% [markdown]
# p->q doesnt mean p causes q
# it means whenever p happens, q must happen
# read it as
# p requires q
# p guarantees q
# p cannot happen without q
# p = it rains
# q = road it wet
# if it rains, the road is wet
#
# reasoning: wet roads dont mean rain always
#
# if i study i pass
# study -> pass
#
#
# if you press the button, the machine starts
# button -> start
#
# i go to the gym if i have time
# time -> gym (wrong)
# gym->time
# trick:
# always what requires what
# and then if a needs b
# then a->b
#
# you graduate only if you pass
# graduate->pass
# you eat dessert only if you finish dinner
# dessert -> dinner finished
#
# only if means then the thing after "only if" is necessary
#
# you enter the lab if and only if you have a ID
# p<->q
#
# scoring 90 marks is sufficient to pass
# 90 marks means passed
# not
# passed means 90 marks
#
# 90 marks->passed
#
# having password is sufficient to login
# password -> login
# air is necessary for fire
#
# fire needs air
# fire->air
#
# a is necessary for b => b->a
#
# you can watch netflix only if you have internet
#
# internet is necessary for netflix
#
# netflix -> internet
#
# winning is sufficient for qualification
# winning needs qualification
# winning->qualification
#
# passport is necessary for travel
# travel -> passport
#
# The arrow always points
#
# from
#
# the thing that DEPENDS
#
# towards
#
# the thing it DEPENDS ON.
#
# dependent -> independent
#
# whenever it rains, the road becomes wet
# rain->wet
#
# you cannot enter unless you have an ID
# enter -> having ID
# OR
# no id->no entry
#
# you pass provided that you study
# study->pass
#
# you may drive as long you have a license
# license ->drive
#
# fire needs oxygen
# fire -> oxygen
#
# p-> q = proposition
# q->p = converse
# contrapositive = -q -> -p
# inverse = -p -> -q
#
#
# satisfiable - if at least one truth assignment makes proposition true
# unsatisfiable - no truth assignment works
# tautology - always true
#
# sufficient -> necessary
# p->q
#
# | English           | Logic            |
# | ----------------- | ---------------- |
# | **and / but**     | and              |
# | **not**           | negate           |
# | **if / whenever** | ->               |
# | **if A, then B**  | A->B             |
