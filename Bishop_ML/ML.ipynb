# %% [markdown]
# we have data, we observe it and find patterns and use patterns to make predictions/decisions
#
# problem:
# given an image, recognize digit
# problem is: huge variation in appearance + same underlying class
# ML tries to learn common structure despite variation
#
# why not just hardcode? then if orientation or font changes its a proliferation of rules and exceptions
#
# say we take 7
# we can have it as a target vector
# ![image.png](attachment:image.png)
#
# this is called one-hot encoding
#
# the learning/training phase:
# training examples - algorithm - model
#
#
# The ability to categorize correctly new examples that differ from those used for training is known as generalization.
#
#
# to avoid overfitting or memorization, we have training/testing split
#
# ![image-2.png](attachment:image-2.png)
#
# preprocessing - handling data before learning to remove faults or defects and make it suitable for training
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# feature extraction leads to dimensionality reduction - useful feature filtering
#
# but preprocessing isnt good always, what if you remove useful features? - thats bad!
#
# ![image-5.png](attachment:image-5.png)
#
# supervised learning - both x and y given find relation btn x and y
# unsupervised learning - only data and inputs,  given u have to figure out the pattern
# ![image-6.png](attachment:image-6.png)
#
# state-> action->reward->new state
#
# exploration vs exploitation - explore to find maybe better methods, exploitation use already found good emthods
# good RL balances both
#
# real world problems:
# True relationship
#        ↓
#     sin(2πx)
#        +
#      noise
#        ↓
# Observed points
#
# want model that is simple enuf and complex enuf, no high bias and no high variance
#
# collect data(EDA) -> representation (preprocessing and feature extraction) -> learning -> prediction/decision
#
# model-> fit->overfitting-> generalization->regularization-> validation
#
# observed target = underlying function + random noise
#
# the order of the model is the complexity
#
# linear wrt w, b but non linear wrt x
#
# ![image-7.png](attachment:image-7.png)
#
# M=0 -> underfitting,
# M=1-> underfitting
# M=3-> good balance
# M=9->overfitting
#
# underfitting model doesnt capture the data well
# a good model captures data well without chasing noise
# overfitting model captures even the noise unnecessarily
#
# bias-variance tradeoff
# initially increasing model complexity leads to better testing results, but after a point it overfits
# high complexity -> overfitting -> poor generalization
#
# low training error doesnt mean good model
#
# Erms error is useful for averaging out for varying sample sizes
#
# more data-> more reliable model
#
# complex model + little data-> high overfitting risk
# complex model + lots of data-> potentially okay
#
# while making a complex model, the coeffecients can be chosen really large to fit the points, so this leads to regularization (parameter restricting)
#
# ![image-8.png](attachment:image-8.png)
#
# ways of overfitting:
# 1. simplify model
# 2. maintain sample model but penalize compelxity
#
# too little regularization - overfitting
# too much regularization - underfitting
#
# ![image-9.png](attachment:image-9.png)
#
# ![image-10.png](attachment:image-10.png)
#
# number of parameters isnt necessarily the same thing as effective complexity
# as by setting lambda high, the coefficients lose value, leading to lowered complexity
#
# ![image-11.png](attachment:image-11.png)
#
# ![image-12.png](attachment:image-12.png)
#
#                  TRUE FUNCTION
#                  t = sin(2πx)
#                        │
#                        ↓
#                  Add noise
#                        │
#                        ↓
#                  Training data
#                        │
#                        ↓
#               Choose polynomial
#                        │
#              ┌─────────┴─────────┐
#              ↓                   ↓
#           Low M                High M
#              ↓                   ↓
#         Underfitting          Overfitting
#              │                   │
#              └─────────┬─────────┘
#                        ↓
#                 Choose complexity
#                        │
#               via validation data
#                        │
#                        ↓
#                  Good model
#                        │
#                        ↓
#              Generalizes to new data
#
# High-degree model
#        ↓
# Regularization
#        ↓
# Penalize large weights
#        ↓
# Reduce effective complexity
#        ↓
# Reduce overfitting
#
# ![image-13.png](attachment:image-13.png)
#
# overfitting = mistaking noise for useful features
#
# ![image-14.png](attachment:image-14.png)
#
# random variable is a variable whose value is uncertain before we observe the outcome
#
# ![image-15.png](attachment:image-15.png)
#
# P(X=xi, Y=yi) means probability both X=xi and Y=yi happen together
#
# prior - what you believe before having new evidence
# likelihood- how probable is the observed evidence under given hypothesis
# posterior - updated belief after new evidence
#
# ![image-16.png](attachment:image-16.png)
#
# ![image-17.png](attachment:image-17.png)
#
# ![image-18.png](attachment:image-18.png)
#
# ![image-19.png](attachment:image-19.png)
#
# ![image-20.png](attachment:image-20.png)
